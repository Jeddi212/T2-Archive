# %%
if __name__ == "__main__":
    
    NEGATION = '\u00ac'
    UNIVERSAL = '\u2200'
    EXISTENSIAL = '\u2203' 
    
    LIST_FAKTA = [ 
        {'nama': 'Abi', 'kelas': 'A', 'suka_mi_instan': True},
        {'nama': 'Ati', 'kelas': 'A', 'suka_mi_instan': True},
        {'nama': 'Ami', 'kelas': 'A', 'suka_mi_instan': True},
        {'nama': 'Edi', 'kelas': 'B', 'suka_mi_instan': False},
        {'nama': 'Eri', 'kelas': 'B', 'suka_mi_instan': True},
        {'nama': 'Egi', 'kelas': 'B', 'suka_mi_instan': True},
        {'nama': 'Ica', 'kelas': 'C', 'suka_mi_instan': False},
        {'nama': 'Ifa', 'kelas': 'C', 'suka_mi_instan': False},
        {'nama': 'Iwa', 'kelas': 'C', 'suka_mi_instan': False}
    ]
    
    LIST_MAHASISWA_A = [fakta['nama'] for fakta in LIST_FAKTA if fakta['kelas'] == 'A']
    LIST_MAHASISWA_B = [fakta['nama'] for fakta in LIST_FAKTA if fakta['kelas'] == 'B'] 
    LIST_MAHASISWA_C = [fakta['nama'] for fakta in LIST_FAKTA if fakta['kelas'] == 'C'] 
    
    print("List Mahasiswa kelas A : ", LIST_MAHASISWA_A)
    print("List Mahasiswa kelas A : ", LIST_MAHASISWA_B)
    print("List Mahasiswa kelas A : ", LIST_MAHASISWA_C)
    
    def suka_mie_instan(NAMA):
        for mahasiswa in LIST_FAKTA:
            if mahasiswa['nama'] == NAMA:
                return mahasiswa['suka_mi_instan']
                break;
    
    print("")
    
    ica = suka_mie_instan('Ica')
    print("Ica suka mie instan ?", ica)
    
    eri = suka_mie_instan('Eri')
    print("Eri suka mi instan ?", eri)
    
    print("")
    
    def cetak_fakta_kelas(listM):
        cek = []
        for data in listM:
            hasil = suka_mie_instan(data)
            print('{:11}{:>14}'.format((data), (hasil)))
            index = 0
            cek.append(hasil)
        
        print("")
        
        semua = None
        ada = None
        
        if ((cek[0] == True) and (cek[1] == True) and (cek[2] == True)):
            semua = True
        else:
            semua = False
        print('{:<24}{:>1}{:<30}'.format(("Semua ?"), (semua), (" (semua mahasiswa kelas ini suka mi instan ?)")))
        
        if ((cek[0] == True) and (cek[1] == True) and (cek[2] == True)):
            ada = True
        else:
            ada = False
        
        print('{:<24}{:>1}{:<30}'.format(("Ada ?"), (ada), (" (ada mahasiswa kelas ini yang suka mi ?)")))
    
    
    print("\nFakta mahasiswa kelas A")
    print("Mahasiswa Suka Mi Instan")
    cetak_fakta_kelas(LIST_MAHASISWA_A)
    
    print("")
    
    print("\nFakta mahasiswa kelas B")
    print("Mahasiswa Suka Mi Instan")
    cetak_fakta_kelas(LIST_MAHASISWA_B)
    
    print("")
    
    print("\nFakta mahasiswa kelas C")
    print("Mahasiswa Suka Mi Instan")
    cetak_fakta_kelas(LIST_MAHASISWA_C)
# Out:
# List Mahasiswa kelas A :  ['Abi', 'Ati', 'Ami']
# List Mahasiswa kelas A :  ['Edi', 'Eri', 'Egi']
# List Mahasiswa kelas A :  ['Ica', 'Ifa', 'Iwa']
#
# Ica suka mie instan ? False
# Eri suka mi instan ? True
#
#
# Fakta mahasiswa kelas A
# Mahasiswa Suka Mi Instan
# Abi                     1
# Ati                     1
# Ami                     1
#
# Semua ?                 1 (semua mahasiswa kelas ini suka mi instan ?)
# Ada ?                   1 (ada mahasiswa kelas ini yang suka mi ?)
#
#
# Fakta mahasiswa kelas B
# Mahasiswa Suka Mi Instan
# Edi                     0
# Eri                     1
# Egi                     1
#
# Semua ?                 0 (semua mahasiswa kelas ini suka mi instan ?)
# Ada ?                   0 (ada mahasiswa kelas ini yang suka mi ?)
#
#
# Fakta mahasiswa kelas C
# Mahasiswa Suka Mi Instan
# Ica                     0
# Ifa                     0
# Iwa                     0
#
# Semua ?                 0 (semua mahasiswa kelas ini suka mi instan ?)
# ...
